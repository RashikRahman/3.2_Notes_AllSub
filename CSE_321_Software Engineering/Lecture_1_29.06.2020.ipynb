# %% [markdown]
# <div class="alert alert-success">
#     <b>Author</b>:
#
#       Rashik Rahman
#       17201012@uap-bd.edu
#
# </div>

# %% [markdown]
# # Video Link : https://photos.app.goo.gl/Uh21ZHMFhKZc9XQz9

# %% [markdown]
# ![image.png](figures/fig1.PNG)<br>
# ![image.png](figures/fig2.PNG)<br>
# ![image.png](figures/fig3.PNG)<br>
# ![image.png](figures/fig4.PNG)<br>
# ![image.png](figures/fig6.PNG)

# %% [markdown]
# # There's nothing much to learn/make notes from this lecture. See slide and if you want you can see the recorded video.
